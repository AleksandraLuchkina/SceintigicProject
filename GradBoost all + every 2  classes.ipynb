# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('facies_vectors_0.csv')
feature_names = ['GR', 'ILD_log10', 'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS','GR_diff_up', 'ILD_log10_diff_up', 'DeltaPHI_diff_up', 'PHIND_diff_up', 'PE_diff_up', 'NM_M_diff_up', 'RELPOS_diff_up']
feature_names_23 = ['GR_diff_up', 'ILD_log10_diff_up', 'DeltaPHI_diff_up', 'PHIND_diff_up', 'PE_diff_up', 'NM_M_diff_up', 'RELPOS_diff_up','GR_diff_down', 'ILD_log10_diff_down', 'DeltaPHI_diff_down', 'PHIND_diff_down', 'PE_diff_down', 'NM_M_diff_down', 'RELPOS_diff_down','GR', 'ILD_log10', 'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS']
feature_names_original = ['GR', 'ILD_log10', 'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS']
data = data.fillna(data['PE'].mean())

# %%
def find_diff(row, well):
    if len(prev_depth_features[well]) == 0:
        prev_depth_features[well] = row.values[4:]
        return
    diff = row.values[4:] - prev_depth_features[well]
    prev_depth_features[well] = row.values[4:]
    return diff
data_well = dict()
data_well_inverse = dict()
prev_depth_features = dict()
new_data = pd.DataFrame()
prev_class= dict()
data_save = pd.DataFrame()
for well in set(data['Well Name']):
    prev_depth_features[well] = []
    prev_class[well] = []
    data_well[well] = data[data['Well Name'] == well]
    data_well[well] = data_well[well].sort_values(by=['Depth'])
    data_save = data_well[well].iloc[::-1]
    data_well[well]['diff_up'] = data_well[well].apply(lambda row: find_diff(row, well), axis=1)
    prev_depth_features[well] = []
    prev_class[well] = []

    data_well[well] = data_well[well].dropna()
    data_well[well]['GR_diff_up'] = data_well[well].apply(lambda row: row['diff_up'][0], axis=1)
    data_well[well]['ILD_log10_diff_up'] = data_well[well].apply(lambda row: row['diff_up'][1], axis=1)
    data_well[well]['DeltaPHI_diff_up'] = data_well[well].apply(lambda row: row['diff_up'][2], axis=1)
    data_well[well]['PHIND_diff_up'] = data_well[well].apply(lambda row: row['diff_up'][3], axis=1)
    data_well[well]['PE_diff_up'] = data_well[well].apply(lambda row: row['diff_up'][4], axis=1)
    data_well[well]['NM_M_diff_up'] = data_well[well].apply(lambda row: row['diff_up'][5], axis=1)
    data_well[well]['RELPOS_diff_up'] = data_well[well].apply(lambda row: row['diff_up'][6], axis=1)

    new_data = pd.concat([new_data, data_well[well]])
    new_data = new_data.drop(['diff_up'], axis=1)

# %%
def augment_features_window(X, N_neig):
    N_row = X.shape[0]
    N_feat = X.shape[1]
    X = np.vstack((np.zeros((N_neig, N_feat)),np.zeros((N_neig, N_feat)), X, np.zeros((N_neig, N_feat)),np.zeros((N_neig, N_feat))))
    X_aug = np.zeros((N_row, N_feat*(4*N_neig+1)))
    for r in np.arange(N_row) + N_neig:
        this_row = []
        for c in np.arange(-N_neig,N_neig+1):
            this_row = np.hstack((this_row, X[r+c]))
            if c != 0:
                this_row = np.hstack((this_row, (X[r] + X[r+c])/2))
        #print(len(this_row))
        X_aug[r-N_neig] = this_row

    return X_aug

def augment_features_gradient(X, depth):
    d_diff = np.diff(depth).reshape((-1, 1))
    d_diff[d_diff==0] = 0.001
    X_diff = np.diff(X, axis=0)
    X_grad = X_diff / d_diff
    X_grad = np.concatenate((X_grad, np.zeros((1, X_grad.shape[1]))))
    
    return X_grad

def augment_features(X, well, depth, N_neig=1):
    X_aug = np.zeros((X.shape[0], X.shape[1]*(4*N_neig+1)))
    for w in np.unique(well):
        w_idx = np.where(well == w)[0]
        X_aug_win = augment_features_window(X[w_idx, :], N_neig)
        #print(X_aug_win)
        #X_aug_grad = augment_features_gradient(X[w_idx, :], depth[w_idx])
        #print(X_aug_grad)
        X_aug[w_idx, :] = X_aug_win
        #X_aug[w_idx, :] = np.concatenate((X_aug_win, X_aug_grad), axis=1)
        
    return X_aug

# %%
import numpy as np
import xgboost as xgb
import math
from sklearn.preprocessing import OneHotEncoder

print('start running example to used customized objective function')

params_pair = {'max_depth': 2, 'eta': 0.1, 'silent': 1,
          'objective': 'multi:softprob', 'num_class': 2}
params = {'max_depth': 2, 'eta': 0.1, 'silent': 1,
          'objective': 'multi:softprob', 'num_class': 9}

num_round = 2
def my_softmax(preds, dtrain):
    labels = dtrain.get_label()
    labels_hot = OneHotEncoder(sparse=False, n_values=9).fit_transform(labels.reshape(-1, 1))
    grad = preds - labels_hot
    hess = preds * (1.0-preds)

    return grad.flatten(), hess.flatten()
def my_softmax_pair(preds, dtrain):
    labels = dtrain.get_label()
    labels_hot = OneHotEncoder(sparse=False, n_values=2).fit_transform(labels.reshape(-1, 1))
    grad = preds - labels_hot
    hess = preds * (1.0-preds)

    return grad.flatten(), hess.flatten()
# Out:
# start running example to used customized objective function

# %%
def number_of_outlier(y_res):
    outliers = 0
    if y_res[0] != y_res[1]:
        outliers += 1
    if y_res[-1] != y_res[-2]:
        outliers += 1
    for index in range(1,len(y_res)-1):
        if ((y_res[index] != y_res[index-1]) and (y_res[index] != y_res[index+1])):
            outliers += 1
    return outliers/len(y_res)

# %%
def most_similar(y_res, y_test):
    for index in range(len(y_res)):
        if (y_res[index] != y_test[index]):
            classes[y_res[index], y_test[index]] += 1

# %%
def scorepair(y_pred, y_test, class1, class2):
    y_pred_pair = []
    y_test_pair = []
    for index in range(len(y_test)):
        if ((y_test[index] == class1) or (y_test[index] == class2)):
            y_test_pair.append(y_test[index])
            y_pred_pair.append(y_pred[index])
    return f1_score(y_test_pair, y_pred_pair , average='micro')

# %%
def foundclass(y_pred, y_test, class1):
    y_class = 0
    sum_class = 0
    for index in range(len(y_test)):
        if (y_test[index] == class1):
            sum_class += 1
            if (y_pred[index] == class1):
                y_class += 1
    if (sum_class == 0):
        return 0
    return y_class/sum_class

def falsefoundclass(y_pred, y_test, class1):
    y_class = 0
    sum_class = 0
    for index in range(len(y_test)):
        if (y_pred[index] == class1):
            sum_class += 1
        if (y_test[index] != class1 and y_pred[index] == class1):
            y_class += 1
    if (sum_class == 0):
        return 0
    return y_class/sum_class

def better(y_pred1, y_pred2, y_test):
    bet = 0
    for index in range(len(y_test)):
        if (y_pred1[index] != y_test[index] and y_pred2[index] == y_test[index]):
            bet +=1
    return bet

def worse(y_pred1, y_pred2, y_test):
    wor = 0
    for index in range(len(y_test)):
        if (y_pred1[index] == y_test[index] and y_pred2[index] != y_test[index]):
            wor +=1
    return wor

def change_sum(y_pred1, y_pred2):
    sum_ = 0
    for index in range(len(y_pred1)):
        if (y_pred1[index] != y_pred2[index]):
            sum_ += 1
    return sum_

# %%
import numpy.random as random
import copy
from sklearn.cluster import KMeans
test = dict()
train = dict()
test_all_pair= dict()
train_all_pair = dict()
acc_pair = 0
classes = dict()
for class1 in range(9):
    for class2 in range (9):
        classes[class1, class2] = 0
acc = 0
wells = set(data['Well Name'])
# wells_68 = set(new_data_68['Well Name'])
change = 0
for well in wells:
# well = 'SHRIMPLIN'
    print(well)
    test[well] = new_data[new_data['Well Name'] == well]
    train[well] = new_data[new_data['Well Name'] != well]
    X_train = train[well][feature_names].values 
    y_train = train[well]['Facies'].values 
    X_test = test[well][feature_names].values
#     X_test = X_test[0:-1]
    y_test = test[well]['Facies'].values 
#     y_test = y_test[0:-1]
    well_train = train[well]['Well Name'].values
    well_test = test[well]['Well Name'].values
#     well_test = well_test[0:-1]
    depth_train = train[well]['Depth'].values
    depth_test = test[well]['Depth'].values   
#     depth_test = depth_test[0:-1]
     
    X_aug_train = augment_features(X_train,well_train,depth_train)
    X_aug_test = augment_features(X_test,well_test,depth_test)

    robust = preprocessing.RobustScaler(quantile_range=(25.0, 75.0)).fit(X_aug_train)
    X_train_robust = robust.transform(X_aug_train)
    X_test_robust = robust.transform(X_aug_test)

    scaler = StandardScaler().fit(X_train_robust)
    X_train_robust_norm = scaler.transform(X_train_robust)
    X_test_robust_norm = scaler.transform(X_test_robust)
    
    dtrain = xgb.DMatrix(X_train_robust_norm, label=y_train)
    dtest = xgb.DMatrix(X_test_robust_norm, label=y_test)
    watchlist = [(dtest, 'eval'), (dtrain, 'train')]
    model = xgb.Booster(params, [dtrain])
    for _ in range(150):
        pred = model.predict(dtrain)
        g, h = my_softmax(pred, dtrain)
        model.boost(dtrain, g, h)
    yhat = model.predict(dtest)
    yhat_labels = np.argmax(yhat, axis=1)
    print("BEFORE ", f1_score(y_test, yhat_labels, average='micro'))
    
    yhat_labels_prev = copy.deepcopy(yhat_labels)
    for class1 in range(8):
        for class2 in range(class1+1, 9):
            new_data_class1 = new_data[new_data['Facies'] == class1]
            new_data_class2 = new_data[new_data['Facies'] == class2]
            new_data_pair = pd.concat([new_data_class1, new_data_class2])
            wells_pair = set(new_data_pair['Well Name'])
            if (well in wells_pair):
                indeces_notpair = []
                for index in range(len(y_train)):
                    if ((y_train[index] != class1) and (y_train[index] != class2)):
                        indeces_notpair.append(index)
        
                X_train_robust_norm_pair = np.delete(X_train_robust_norm, indeces_notpair, 0)
                y_train_pair = np.delete(y_train, indeces_notpair)
        
                for index in range(len(y_train_pair)):
                    if (y_train_pair[index] == class1):
                        y_train_pair[index] = 0
                    if (y_train_pair[index] == class2):
                        y_train_pair[index] = 1
            
                indeces_notpair = []
                for index in range(len(yhat_labels)):
                    if ((yhat_labels[index] != class1) and (yhat_labels[index] != class2)):
                        indeces_notpair.append(index)
        
                X_test_robust_norm_pair = np.delete(X_test_robust_norm, indeces_notpair, 0)
                if (len(X_test_robust_norm_pair) == 0):
                    continue
                y_test_pair = np.delete(y_test, indeces_notpair)
        
                dtrain_pair = xgb.DMatrix(np.array(X_train_robust_norm_pair), label=np.array(y_train_pair))
                dtest_pair = xgb.DMatrix(np.array(X_test_robust_norm_pair), label=np.array(y_test_pair))
                watchlist = [(dtest_pair, 'eval'), (dtrain_pair, 'train')]
        
                model_pair = xgb.Booster(params_pair, [dtrain_pair])
                for _ in range(150):
                    pred = model_pair.predict(dtrain_pair)
                    g, h = my_softmax_pair(pred, dtrain_pair)
                    model_pair.boost(dtrain_pair, g, h)
        
                yhat_pair = model_pair.predict(dtest_pair)
                yhat_labels_pair = np.argmax(yhat_pair, axis=1)
        
                for index in range(len(yhat_labels_pair)):
                    if (yhat_labels_pair[index] == 0):
                        yhat_labels_pair[index] = class1
                    if (yhat_labels_pair[index] == 1):
                        yhat_labels_pair[index] = class2

                ind = 0
                for index in range(len(yhat_labels)):
                    if index not in indeces_notpair:
                        if ((yhat_labels[index] == class1) and (yhat_labels_pair[ind] == class2)):
                            change += 1
                        if ((yhat_labels[index] == class1) and (yhat_labels_pair[ind] == class2)):
                            change += 1
                        yhat_labels[index] = yhat_labels_pair[ind]
                        ind  += 1
                print("True detected ", class1, " ", foundclass(yhat_labels_prev, y_test, class1))
                print("False detected ", class1, " ",  falsefoundclass(yhat_labels_prev, y_test, class1))
                print("True detected ", class2, " ",  foundclass(yhat_labels_prev, y_test, class2))
                print("False detected ", class2, " ",  falsefoundclass(yhat_labels_prev, y_test, class2))
                print("Better results, id ", better(yhat_labels_prev, yhat_labels, y_test))
                print("Worse results, id ", worse(yhat_labels_prev, yhat_labels, y_test))
                print("Change ", change_sum(yhat_labels_prev, yhat_labels))
                print("AFTER ", class1, " ", class2, " ", f1_score(y_test, yhat_labels, average='micro'))
    acc += f1_score(y_test, yhat_labels, average='micro')
    print("AFTER ", f1_score(y_test, yhat_labels, average='micro'))
#     print("Score on train ", f1_score(y_train, yhat_labels_train , average='micro'))
#     print("Outliers test", number_of_outlier(y_test))
#     print("Outliers res", number_of_outlier(yhat_labels))
#     print("Change ", change)
    most_similar(yhat_labels, y_test)
print('well, boosting of trees, ', acc/10)  
print('well, boosting of trees 68, ', acc_68/9) 
print(change)
# Out:
# NEWBY
# BEFORE  0.5865800865800865
# True detected  0   0.0
# False detected  0   0
# True detected  2   0.7551020408163265
# False detected  2   0.308411214953271
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   2   0.5865800865800865
# True detected  0   0.0
# False detected  0   0
# True detected  3   0.5822784810126582
# False detected  3   0.3333333333333333
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   3   0.5865800865800865
# True detected  0   0.0
# False detected  0   0
# True detected  4   0.7068965517241379
# False detected  4   0.18
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   4   0.5865800865800865
# True detected  0   0.0
# False detected  0   0
# True detected  5   0.03571428571428571
# False detected  5   0.6666666666666666
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   5   0.5865800865800865
# True detected  0   0.0
# False detected  0   0
# True detected  6   0.5833333333333334
# False detected  6   0.45098039215686275
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   6   0.5865800865800865
# True detected  0   0.0
# False detected  0   0
# True detected  7   0.625
# False detected  7   0.5
# Better results, id  1
# Worse results, id  0
# Change  4
# AFTER  0   7   0.5887445887445888
# True detected  0   0.0
# False detected  0   0
# True detected  8   0.7678571428571429
# False detected  8   0.6126126126126126
# Better results, id  0
# Worse results, id  0
# Change  4
# AFTER  0   8   0.5865800865800865
# True detected  1   0
# False detected  1   0
# True detected  2   0.7551020408163265
# False detected  2   0.308411214953271
# Better results, id  0
# Worse results, id  0
# Change  4
# AFTER  1   2   0.5865800865800865
# True detected  1   0
# False detected  1   0
# True detected  3   0.5822784810126582
# False detected  3   0.3333333333333333
# Better results, id  0
# Worse results, id  0
# Change  4
# AFTER  1   3   0.5865800865800865
# True detected  1   0
# False detected  1   0
# True detected  4   0.7068965517241379
# False detected  4   0.18
# Better results, id  0
# Worse results, id  0
# Change  4
# AFTER  1   4   0.5865800865800865
# True detected  1   0
# False detected  1   0
# True detected  5   0.03571428571428571
# False detected  5   0.6666666666666666
# Better results, id  0
# Worse results, id  0
# Change  4
# AFTER  1   5   0.5865800865800865
# True detected  1   0
# False detected  1   0
# True detected  6   0.5833333333333334
# False detected  6   0.45098039215686275
# Better results, id  0
# Worse results, id  0
# Change  4
# AFTER  1   6   0.5865800865800865
# True detected  1   0
# False detected  1   0
# True detected  7   0.625
# False detected  7   0.5
# Better results, id  0
# Worse results, id  0
# Change  4
# AFTER  1   7   0.5865800865800865
# True detected  1   0
# False detected  1   0
# True detected  8   0.7678571428571429
# False detected  8   0.6126126126126126
# Better results, id  0
# Worse results, id  0
# Change  4
# AFTER  1   8   0.5865800865800865
# True detected  2   0.7551020408163265
# False detected  2   0.308411214953271
# True detected  3   0.5822784810126582
# False detected  3   0.3333333333333333
# Better results, id  4
# Worse results, id  5
# Change  13
# AFTER  2   3   0.5844155844155844
# True detected  2   0.7551020408163265
# False detected  2   0.308411214953271
# True detected  4   0.7068965517241379
# False detected  4   0.18
# Better results, id  4
# Worse results, id  5
# Change  13
# AFTER  2   4   0.5844155844155844
# True detected  2   0.7551020408163265
# False detected  2   0.308411214953271
# True detected  5   0.03571428571428571
# False detected  5   0.6666666666666666
# Better results, id  4
# Worse results, id  5
# Change  13
# AFTER  2   5   0.5844155844155844
# True detected  2   0.7551020408163265
# False detected  2   0.308411214953271
# True detected  6   0.5833333333333334
# False detected  6   0.45098039215686275
# Better results, id  4
# Worse results, id  5
# Change  14
# AFTER  2   6   0.5844155844155844
# True detected  2   0.7551020408163265
# False detected  2   0.308411214953271
# True detected  7   0.625
# False detected  7   0.5
# Better results, id  4
# Worse results, id  5
# Change  14
# AFTER  2   7   0.5844155844155844
# True detected  2   0.7551020408163265
# False detected  2   0.308411214953271
# True detected  8   0.7678571428571429
# False detected  8   0.6126126126126126
# Better results, id  4
# Worse results, id  5
# Change  14
# AFTER  2   8   0.5844155844155844
# True detected  3   0.5822784810126582
# False detected  3   0.3333333333333333
# True detected  4   0.7068965517241379
# False detected  4   0.18
# Better results, id  4
# Worse results, id  5
# Change  15
# AFTER  3   4   0.5844155844155844
# True detected  3   0.5822784810126582
# False detected  3   0.3333333333333333
# True detected  5   0.03571428571428571
# False detected  5   0.6666666666666666
# Better results, id  4
# Worse results, id  5
# Change  15
# AFTER  3   5   0.5844155844155844
# True detected  3   0.5822784810126582
# False detected  3   0.3333333333333333
# True detected  6   0.5833333333333334
# False detected  6   0.45098039215686275
# Better results, id  4
# Worse results, id  5
# Change  15
# AFTER  3   6   0.5844155844155844
# True detected  3   0.5822784810126582
# False detected  3   0.3333333333333333
# True detected  7   0.625
# False detected  7   0.5
# Better results, id  4
# Worse results, id  5
# Change  15
# AFTER  3   7   0.5844155844155844
# True detected  3   0.5822784810126582
# False detected  3   0.3333333333333333
# True detected  8   0.7678571428571429
# False detected  8   0.6126126126126126
# Better results, id  4
# Worse results, id  6
# Change  17
# AFTER  3   8   0.5822510822510822
# True detected  4   0.7068965517241379
# False detected  4   0.18
# True detected  5   0.03571428571428571
# False detected  5   0.6666666666666666
# Better results, id  5
# Worse results, id  6
# Change  18
# AFTER  4   5   0.5844155844155844
# True detected  4   0.7068965517241379
# False detected  4   0.18
# True detected  6   0.5833333333333334
# False detected  6   0.45098039215686275
# Better results, id  6
# Worse results, id  9
# Change  22
# AFTER  4   6   0.5800865800865801
# True detected  4   0.7068965517241379
# False detected  4   0.18
# True detected  7   0.625
# False detected  7   0.5
# Better results, id  6
# Worse results, id  9
# Change  22
# AFTER  4   7   0.5800865800865801
# True detected  4   0.7068965517241379
# False detected  4   0.18
# True detected  8   0.7678571428571429
# False detected  8   0.6126126126126126
# Better results, id  5
# Worse results, id  9
# Change  22
# AFTER  4   8   0.577922077922078
# True detected  5   0.03571428571428571
# False detected  5   0.6666666666666666
# True detected  6   0.5833333333333334
# False detected  6   0.45098039215686275
# Better results, id  5
# Worse results, id  10
# Change  24
# AFTER  5   6   0.5757575757575758
# True detected  5   0.03571428571428571
# False detected  5   0.6666666666666666
# True detected  7   0.625
# False detected  7   0.5
# Better results, id  5
# Worse results, id  10
# Change  24
# AFTER  5   7   0.5757575757575758
# True detected  5   0.03571428571428571
# False detected  5   0.6666666666666666
# True detected  8   0.7678571428571429
# False detected  8   0.6126126126126126
# Better results, id  7
# Worse results, id  10
# Change  26
# AFTER  5   8   0.5800865800865801
# True detected  6   0.5833333333333334
# False detected  6   0.45098039215686275
# True detected  7   0.625
# False detected  7   0.5
# Better results, id  8
# Worse results, id  10
# Change  27
# AFTER  6   7   0.5822510822510822
# True detected  6   0.5833333333333334
# False detected  6   0.45098039215686275
# True detected  8   0.7678571428571429
# False detected  8   0.6126126126126126
# Better results, id  13
# Worse results, id  13
# Change  38
# AFTER  6   8   0.5865800865800865
# True detected  7   0.625
# False detected  7   0.5
# True detected  8   0.7678571428571429
# False detected  8   0.6126126126126126
# Better results, id  15
# Worse results, id  14
# Change  43
# AFTER  7   8   0.5887445887445888
# AFTER  0.5887445887445888
# SHRIMPLIN
# BEFORE  0.648936170212766
# True detected  0   1.0
# False detected  0   0.5
# True detected  1   0
# False detected  1   1.0
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   1   0.648936170212766
# True detected  0   1.0
# False detected  0   0.5
# True detected  2   0.6694915254237288
# False detected  2   0.21
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   2   0.648936170212766
# True detected  0   1.0
# False detected  0   0.5
# True detected  3   0.8278688524590164
# False detected  3   0.2462686567164179
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   3   0.648936170212766
# True detected  0   1.0
# False detected  0   0.5
# True detected  4   0.6111111111111112
# False detected  4   0.6071428571428571
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   4   0.648936170212766
# True detected  0   1.0
# False detected  0   0.5
# True detected  5   0.14285714285714285
# False detected  5   0.18181818181818182
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   5   0.648936170212766
# True detected  0   1.0
# False detected  0   0.5
# True detected  6   0.7301587301587301
# False detected  6   0.5
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  0   6   0.6468085106382979
# True detected  0   1.0
# False detected  0   0.5
# True detected  7   0.0
# False detected  7   1.0
# Better results, id  0
# Worse results, id  1
# Change  3
# AFTER  0   7   0.6468085106382979
# True detected  0   1.0
# False detected  0   0.5
# True detected  8   0.6811594202898551
# False detected  8   0.3561643835616438
# Better results, id  1
# Worse results, id  1
# Change  7
# AFTER  0   8   0.648936170212766
# True detected  1   0
# False detected  1   1.0
# True detected  2   0.6694915254237288
# False detected  2   0.21
# Better results, id  7
# Worse results, id  1
# Change  13
# AFTER  1   2   0.6617021276595745
# True detected  1   0
# False detected  1   1.0
# True detected  3   0.8278688524590164
# False detected  3   0.2462686567164179
# Better results, id  7
# Worse results, id  1
# Change  13
# AFTER  1   3   0.6617021276595745
# True detected  1   0
# False detected  1   1.0
# True detected  4   0.6111111111111112
# False detected  4   0.6071428571428571
# Better results, id  7
# Worse results, id  1
# Change  13
# AFTER  1   4   0.6617021276595745
# True detected  1   0
# False detected  1   1.0
# True detected  5   0.14285714285714285
# False detected  5   0.18181818181818182
# Better results, id  7
# Worse results, id  1
# Change  13
# AFTER  1   5   0.6617021276595745
# True detected  1   0
# False detected  1   1.0
# True detected  6   0.7301587301587301
# False detected  6   0.5
# Better results, id  7
# Worse results, id  1
# Change  13
# AFTER  1   6   0.6617021276595745
# True detected  1   0
# False detected  1   1.0
# True detected  7   0.0
# False detected  7   1.0
# Better results, id  7
# Worse results, id  1
# Change  13
# AFTER  1   7   0.6617021276595745
# True detected  1   0
# False detected  1   1.0
# True detected  8   0.6811594202898551
# False detected  8   0.3561643835616438
# Better results, id  7
# Worse results, id  1
# Change  13
# AFTER  1   8   0.6617021276595745
# True detected  2   0.6694915254237288
# False detected  2   0.21
# True detected  3   0.8278688524590164
# False detected  3   0.2462686567164179
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  2   3   0.648936170212766
# True detected  2   0.6694915254237288
# False detected  2   0.21
# True detected  4   0.6111111111111112
# False detected  4   0.6071428571428571
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  2   4   0.648936170212766
# True detected  2   0.6694915254237288
# False detected  2   0.21
# True detected  5   0.14285714285714285
# False detected  5   0.18181818181818182
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  2   5   0.648936170212766
# True detected  2   0.6694915254237288
# False detected  2   0.21
# True detected  6   0.7301587301587301
# False detected  6   0.5
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  2   6   0.648936170212766
# True detected  2   0.6694915254237288
# False detected  2   0.21
# True detected  7   0.0
# False detected  7   1.0
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  2   7   0.648936170212766
# True detected  2   0.6694915254237288
# False detected  2   0.21
# True detected  8   0.6811594202898551
# False detected  8   0.3561643835616438
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  2   8   0.648936170212766
# True detected  3   0.8278688524590164
# False detected  3   0.2462686567164179
# True detected  4   0.6111111111111112
# False detected  4   0.6071428571428571
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  3   4   0.648936170212766
# True detected  3   0.8278688524590164
# False detected  3   0.2462686567164179
# True detected  5   0.14285714285714285
# False detected  5   0.18181818181818182
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  3   5   0.648936170212766
# True detected  3   0.8278688524590164
# False detected  3   0.2462686567164179
# True detected  6   0.7301587301587301
# False detected  6   0.5
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  3   6   0.648936170212766
# True detected  3   0.8278688524590164
# False detected  3   0.2462686567164179
# True detected  7   0.0
# False detected  7   1.0
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  3   7   0.648936170212766
# True detected  3   0.8278688524590164
# False detected  3   0.2462686567164179
# True detected  8   0.6811594202898551
# False detected  8   0.3561643835616438
# Better results, id  16
# Worse results, id  16
# Change  37
# AFTER  3   8   0.648936170212766
# True detected  4   0.6111111111111112
# False detected  4   0.6071428571428571
# True detected  5   0.14285714285714285
# False detected  5   0.18181818181818182
# Better results, id  16
# Worse results, id  17
# Change  38
# AFTER  4   5   0.6468085106382979
# True detected  4   0.6111111111111112
# False detected  4   0.6071428571428571
# True detected  6   0.7301587301587301
# False detected  6   0.5
# Better results, id  16
# Worse results, id  24
# Change  50
# AFTER  4   6   0.6319148936170212
# True detected  4   0.6111111111111112
# False detected  4   0.6071428571428571
# True detected  7   0.0
# False detected  7   1.0
# Better results, id  16
# Worse results, id  24
# Change  50
# AFTER  4   7   0.6319148936170212
# True detected  4   0.6111111111111112
# False detected  4   0.6071428571428571
# True detected  8   0.6811594202898551
# False detected  8   0.3561643835616438
# Better results, id  16
# Worse results, id  24
# Change  52
# AFTER  4   8   0.6319148936170212
# True detected  5   0.14285714285714285
# False detected  5   0.18181818181818182
# True detected  6   0.7301587301587301
# False detected  6   0.5
# Better results, id  19
# Worse results, id  29
# Change  60
# AFTER  5   6   0.6276595744680851
# True detected  5   0.14285714285714285
# False detected  5   0.18181818181818182
# True detected  7   0.0
# False detected  7   1.0
# Better results, id  18
# Worse results, id  29
# Change  60
# AFTER  5   7   0.625531914893617
# True detected  5   0.14285714285714285
# False detected  5   0.18181818181818182
# True detected  8   0.6811594202898551
# False detected  8   0.3561643835616438
# Better results, id  17
# Worse results, id  30
# Change  62
# AFTER  5   8   0.6212765957446809
# True detected  6   0.7301587301587301
# False detected  6   0.5
# True detected  7   0.0
# False detected  7   1.0
# Better results, id  17
# Worse results, id  30
# Change  61
# AFTER  6   7   0.6212765957446809
# True detected  6   0.7301587301587301
# False detected  6   0.5
# True detected  8   0.6811594202898551
# False detected  8   0.3561643835616438
# Better results, id  20
# Worse results, id  37
# Change  80
# AFTER  6   8   0.6127659574468085
# True detected  7   0.0
# False detected  7   1.0
# True detected  8   0.6811594202898551
# False detected  8   0.3561643835616438
# Better results, id  20
# Worse results, id  37
# Change  81
# AFTER  7   8   0.6127659574468085
# AFTER  0.6127659574468085
# LUKE G U
# BEFORE  0.6413043478260869
# True detected  0   0
# False detected  0   0
# True detected  2   0.6837606837606838
# False detected  2   0.30434782608695654
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   2   0.6413043478260869
# True detected  0   0
# False detected  0   0
# True detected  3   0.6953125
# False detected  3   0.1834862385321101
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   3   0.6413043478260869
# True detected  0   0
# False detected  0   0
# True detected  4   0.8285714285714286
# False detected  4   0.3695652173913043
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   4   0.6413043478260869
# True detected  0   0
# False detected  0   0
# True detected  5   0.5
# False detected  5   0.9375
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   5   0.6413043478260869
# True detected  0   0
# False detected  0   0
# True detected  6   0.4166666666666667
# False detected  6   0.3269230769230769
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   6   0.6413043478260869
# True detected  0   0
# False detected  0   0
# True detected  7   0.35
# False detected  7   0.3
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   7   0.6413043478260869
# True detected  0   0
# False detected  0   0
# True detected  8   0.7297297297297297
# False detected  8   0.4
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   8   0.6413043478260869
# True detected  1   0
# False detected  1   1.0
# True detected  2   0.6837606837606838
# False detected  2   0.30434782608695654
# Better results, id  19
# Worse results, id  0
# Change  23
# AFTER  1   2   0.6826086956521739
# True detected  1   0
# False detected  1   1.0
# True detected  3   0.6953125
# False detected  3   0.1834862385321101
# Better results, id  19
# Worse results, id  0
# Change  23
# AFTER  1   3   0.6826086956521739
# True detected  1   0
# False detected  1   1.0
# True detected  4   0.8285714285714286
# False detected  4   0.3695652173913043
# Better results, id  19
# Worse results, id  0
# Change  23
# AFTER  1   4   0.6826086956521739
# True detected  1   0
# False detected  1   1.0
# True detected  5   0.5
# False detected  5   0.9375
# Better results, id  19
# Worse results, id  0
# Change  23
# AFTER  1   5   0.6826086956521739
# True detected  1   0
# False detected  1   1.0
# True detected  6   0.4166666666666667
# False detected  6   0.3269230769230769
# Better results, id  19
# Worse results, id  0
# Change  23
# AFTER  1   6   0.6826086956521739
# True detected  1   0
# False detected  1   1.0
# True detected  7   0.35
# False detected  7   0.3
# Better results, id  19
# Worse results, id  0
# Change  23
# AFTER  1   7   0.6826086956521739
# True detected  1   0
# False detected  1   1.0
# True detected  8   0.7297297297297297
# False detected  8   0.4
# Better results, id  19
# Worse results, id  0
# Change  23
# AFTER  1   8   0.6826086956521739
# True detected  2   0.6837606837606838
# False detected  2   0.30434782608695654
# True detected  3   0.6953125
# False detected  3   0.1834862385321101
# Better results, id  26
# Worse results, id  11
# Change  41
# AFTER  2   3   0.6739130434782609
# True detected  2   0.6837606837606838
# False detected  2   0.30434782608695654
# True detected  4   0.8285714285714286
# False detected  4   0.3695652173913043
# Better results, id  26
# Worse results, id  11
# Change  41
# AFTER  2   4   0.6739130434782609
# True detected  2   0.6837606837606838
# False detected  2   0.30434782608695654
# True detected  5   0.5
# False detected  5   0.9375
# Better results, id  26
# Worse results, id  11
# Change  41
# AFTER  2   5   0.6739130434782609
# True detected  2   0.6837606837606838
# False detected  2   0.30434782608695654
# True detected  6   0.4166666666666667
# False detected  6   0.3269230769230769
# Better results, id  26
# Worse results, id  11
# Change  41
# AFTER  2   6   0.6739130434782609
# True detected  2   0.6837606837606838
# False detected  2   0.30434782608695654
# True detected  7   0.35
# False detected  7   0.3
# Better results, id  26
# Worse results, id  11
# Change  41
# AFTER  2   7   0.6739130434782609
# True detected  2   0.6837606837606838
# False detected  2   0.30434782608695654
# True detected  8   0.7297297297297297
# False detected  8   0.4
# Better results, id  26
# Worse results, id  11
# Change  41
# AFTER  2   8   0.6739130434782609
# True detected  3   0.6953125
# False detected  3   0.1834862385321101
# True detected  4   0.8285714285714286
# False detected  4   0.3695652173913043
# Better results, id  26
# Worse results, id  11
# Change  41
# AFTER  3   4   0.6739130434782609
# True detected  3   0.6953125
# False detected  3   0.1834862385321101
# True detected  5   0.5
# False detected  5   0.9375
# Better results, id  26
# Worse results, id  11
# Change  42
# AFTER  3   5   0.6739130434782609
# True detected  3   0.6953125
# False detected  3   0.1834862385321101
# True detected  6   0.4166666666666667
# False detected  6   0.3269230769230769
# Better results, id  26
# Worse results, id  11
# Change  42
# AFTER  3   6   0.6739130434782609
# True detected  3   0.6953125
# False detected  3   0.1834862385321101
# True detected  7   0.35
# False detected  7   0.3
# Better results, id  26
# Worse results, id  11
# Change  42
# AFTER  3   7   0.6739130434782609
# True detected  3   0.6953125
# False detected  3   0.1834862385321101
# True detected  8   0.7297297297297297
# False detected  8   0.4
# Better results, id  26
# Worse results, id  11
# Change  43
# AFTER  3   8   0.6739130434782609
# True detected  4   0.8285714285714286
# False detected  4   0.3695652173913043
# True detected  5   0.5
# False detected  5   0.9375
# Better results, id  26
# Worse results, id  14
# Change  48
# AFTER  4   5   0.6673913043478261
# True detected  4   0.8285714285714286
# False detected  4   0.3695652173913043
# True detected  6   0.4166666666666667
# False detected  6   0.3269230769230769
# Better results, id  26
# Worse results, id  16
# Change  52
# AFTER  4   6   0.6630434782608695
# True detected  4   0.8285714285714286
# False detected  4   0.3695652173913043
# True detected  7   0.35
# False detected  7   0.3
# Better results, id  28
# Worse results, id  16
# Change  54
# AFTER  4   7   0.6673913043478261
# True detected  4   0.8285714285714286
# False detected  4   0.3695652173913043
# True detected  8   0.7297297297297297
# False detected  8   0.4
# Better results, id  28
# Worse results, id  16
# Change  55
# AFTER  4   8   0.6673913043478261
# True detected  5   0.5
# False detected  5   0.9375
# True detected  6   0.4166666666666667
# False detected  6   0.3269230769230769
# Better results, id  30
# Worse results, id  18
# Change  64
# AFTER  5   6   0.6673913043478261
# True detected  5   0.5
# False detected  5   0.9375
# True detected  7   0.35
# False detected  7   0.3
# Better results, id  31
# Worse results, id  18
# Change  64
# AFTER  5   7   0.6695652173913044
# True detected  5   0.5
# False detected  5   0.9375
# True detected  8   0.7297297297297297
# False detected  8   0.4
# Better results, id  33
# Worse results, id  18
# Change  65
# AFTER  5   8   0.6739130434782609
# True detected  6   0.4166666666666667
# False detected  6   0.3269230769230769
# True detected  7   0.35
# False detected  7   0.3
# Better results, id  32
# Worse results, id  18
# Change  64
# AFTER  6   7   0.6717391304347826
# True detected  6   0.4166666666666667
# False detected  6   0.3269230769230769
# True detected  8   0.7297297297297297
# False detected  8   0.4
# Better results, id  39
# Worse results, id  24
# Change  78
# AFTER  6   8   0.6739130434782609
# True detected  7   0.35
# False detected  7   0.3
# True detected  8   0.7297297297297297
# False detected  8   0.4
# Better results, id  39
# Worse results, id  24
# Change  78
# AFTER  7   8   0.6739130434782609
# AFTER  0.6739130434782609
# KIMZEY A
# BEFORE  0.5593607305936074
# True detected  0   0.42857142857142855
# False detected  0   0.6666666666666666
# True detected  1   0.0
# False detected  1   0
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   1   0.5593607305936074
# True detected  0   0.42857142857142855
# False detected  0   0.6666666666666666
# True detected  2   0.8235294117647058
# False detected  2   0.32038834951456313
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   2   0.5593607305936074
# True detected  0   0.42857142857142855
# False detected  0   0.6666666666666666
# True detected  3   0.6216216216216216
# False detected  3   0.28125
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   3   0.5593607305936074
# True detected  0   0.42857142857142855
# False detected  0   0.6666666666666666
# True detected  4   0.5813953488372093
# False detected  4   0.2857142857142857
# Better results, id  0
# Worse results, id  0
# Change  2
# AFTER  0   4   0.5593607305936074
# True detected  0   0.42857142857142855
# False detected  0   0.6666666666666666
# True detected  5   0.018867924528301886
# False detected  5   0.6666666666666666
# Better results, id  0
# Worse results, id  0
# Change  3
# AFTER  0   5   0.5593607305936074
# True detected  0   0.42857142857142855
# False detected  0   0.6666666666666666
# True detected  6   0.6274509803921569
# False detected  6   0.7333333333333333
# Better results, id  2
# Worse results, id  0
# Change  6
# AFTER  0   6   0.5639269406392694
# True detected  0   0.42857142857142855
# False detected  0   0.6666666666666666
# True detected  7   0.5555555555555556
# False detected  7   0.4230769230769231
# Better results, id  2
# Worse results, id  0
# Change  7
# AFTER  0   7   0.5639269406392694
# True detected  0   0.42857142857142855
# False detected  0   0.6666666666666666
# True detected  8   0.5888888888888889
# False detected  8   0.32051282051282054
# Better results, id  1
# Worse results, id  0
# Change  7
# AFTER  0   8   0.5616438356164384
# True detected  1   0.0
# False detected  1   0
# True detected  2   0.8235294117647058
# False detected  2   0.32038834951456313
# Better results, id  2
# Worse results, id  0
# Change  7
# AFTER  1   2   0.5639269406392694
# True detected  1   0.0
# False detected  1   0
# True detected  3   0.6216216216216216
# False detected  3   0.28125
# Better results, id  2
# Worse results, id  0
# Change  7
# AFTER  1   3   0.5639269406392694
# True detected  1   0.0
# False detected  1   0
# True detected  4   0.5813953488372093
# False detected  4   0.2857142857142857
# Better results, id  2
# Worse results, id  0
# Change  7
# AFTER  1   4   0.5639269406392694
# True detected  1   0.0
# False detected  1   0
# True detected  5   0.018867924528301886
# False detected  5   0.6666666666666666
# Better results, id  2
# Worse results, id  0
# Change  7
# AFTER  1   5   0.5639269406392694
# True detected  1   0.0
# False detected  1   0
# True detected  6   0.6274509803921569
# False detected  6   0.7333333333333333
# Better results, id  2
# Worse results, id  0
# Change  7
# AFTER  1   6   0.5639269406392694
# True detected  1   0.0
# False detected  1   0
# True detected  7   0.5555555555555556
# False detected  7   0.4230769230769231
# Better results, id  2
# Worse results, id  0
# Change  7
# AFTER  1   7   0.5639269406392694
# True detected  1   0.0
# False detected  1   0
# True detected  8   0.5888888888888889
# False detected  8   0.32051282051282054
# Better results, id  2
# Worse results, id  0
# Change  7
# AFTER  1   8   0.5639269406392694
# True detected  2   0.8235294117647058
# False detected  2   0.32038834951456313
# True detected  3   0.6216216216216216
# False detected  3   0.28125
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  2   3   0.5616438356164384
# True detected  2   0.8235294117647058
# False detected  2   0.32038834951456313
# True detected  4   0.5813953488372093
# False detected  4   0.2857142857142857
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  2   4   0.5616438356164384
# True detected  2   0.8235294117647058
# False detected  2   0.32038834951456313
# True detected  5   0.018867924528301886
# False detected  5   0.6666666666666666
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  2   5   0.5616438356164384
# True detected  2   0.8235294117647058
# False detected  2   0.32038834951456313
# True detected  6   0.6274509803921569
# False detected  6   0.7333333333333333
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  2   6   0.5616438356164384
# True detected  2   0.8235294117647058
# False detected  2   0.32038834951456313
# True detected  7   0.5555555555555556
# False detected  7   0.4230769230769231
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  2   7   0.5616438356164384
# True detected  2   0.8235294117647058
# False detected  2   0.32038834951456313
# True detected  8   0.5888888888888889
# False detected  8   0.32051282051282054
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  2   8   0.5616438356164384
# True detected  3   0.6216216216216216
# False detected  3   0.28125
# True detected  4   0.5813953488372093
# False detected  4   0.2857142857142857
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  3   4   0.5616438356164384
# True detected  3   0.6216216216216216
# False detected  3   0.28125
# True detected  5   0.018867924528301886
# False detected  5   0.6666666666666666
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  3   5   0.5616438356164384
# True detected  3   0.6216216216216216
# False detected  3   0.28125
# True detected  6   0.6274509803921569
# False detected  6   0.7333333333333333
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  3   6   0.5616438356164384
# True detected  3   0.6216216216216216
# False detected  3   0.28125
# True detected  7   0.5555555555555556
# False detected  7   0.4230769230769231
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  3   7   0.5616438356164384
# True detected  3   0.6216216216216216
# False detected  3   0.28125
# True detected  8   0.5888888888888889
# False detected  8   0.32051282051282054
# Better results, id  8
# Worse results, id  7
# Change  22
# AFTER  3   8   0.5616438356164384
# True detected  4   0.5813953488372093
# False detected  4   0.2857142857142857
# True detected  5   0.018867924528301886
# False detected  5   0.6666666666666666
# Better results, id  8
# Worse results, id  7
# Change  23
# AFTER  4   5   0.5616438356164384
# True detected  4   0.5813953488372093
# False detected  4   0.2857142857142857
# True detected  6   0.6274509803921569
# False detected  6   0.7333333333333333
# Better results, id  15
# Worse results, id  9
# Change  43
# AFTER  4   6   0.5730593607305936
# True detected  4   0.5813953488372093
# False detected  4   0.2857142857142857
# True detected  7   0.5555555555555556
# False detected  7   0.4230769230769231
# Better results, id  17
# Worse results, id  9
# Change  43
# AFTER  4   7   0.5776255707762558
# True detected  4   0.5813953488372093
# False detected  4   0.2857142857142857
# True detected  8   0.5888888888888889
# False detected  8   0.32051282051282054
# Better results, id  17
# Worse results, id  11
# Change  46
# AFTER  4   8   0.5730593607305936
# True detected  5   0.018867924528301886
# False detected  5   0.6666666666666666
# True detected  6   0.6274509803921569
# False detected  6   0.7333333333333333
# Better results, id  18
# Worse results, id  11
# Change  48
# AFTER  5   6   0.5753424657534246
# True detected  5   0.018867924528301886
# False detected  5   0.6666666666666666
# True detected  7   0.5555555555555556
# False detected  7   0.4230769230769231
# Better results, id  16
# Worse results, id  11
# Change  48
# AFTER  5   7   0.5707762557077626
# True detected  5   0.018867924528301886
# False detected  5   0.6666666666666666
# True detected  8   0.5888888888888889
# False detected  8   0.32051282051282054
# Better results, id  16
# Worse results, id  11
# Change  49
# AFTER  5   8   0.5707762557077626
# True detected  6   0.6274509803921569
# False detected  6   0.7333333333333333
# True detected  7   0.5555555555555556
# False detected  7   0.4230769230769231
# Better results, id  16
# Worse results, id  13
# Change  53
# AFTER  6   7   0.5662100456621004
# True detected  6   0.6274509803921569
# False detected  6   0.7333333333333333
# True detected  8   0.5888888888888889
# False detected  8   0.32051282051282054
# Better results, id  27
# Worse results, id  20
# Change  71
# AFTER  6   8   0.5753424657534246
# True detected  7   0.5555555555555556
# False detected  7   0.4230769230769231
# True detected  8   0.5888888888888889
# False detected  8   0.32051282051282054
# Better results, id  29
# Worse results, id  23
# Change  76
# AFTER  7   8   0.5730593607305936
# AFTER  0.5730593607305936
# Recruit F9
# BEFORE  0.7974683544303798
# True detected  0   0.7974683544303798
# False detected  0   0.0
# True detected  1   0
# False detected  1   1.0
# Better results, id  1
# Worse results, id  0
# Change  1
# AFTER  0   1   0.810126582278481
# True detected  0   0.7974683544303798
# False detected  0   0.0
# True detected  2   0
# False detected  2   0
# Better results, id  1
# Worse results, id  0
# Change  1
# AFTER  0   2   0.810126582278481
# True detected  0   0.7974683544303798
# False detected  0   0.0
# True detected  3   0
# False detected  3   0
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   3   0.7974683544303798
# True detected  0   0.7974683544303798
# False detected  0   0.0
# True detected  4   0
# False detected  4   0
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   4   0.7974683544303798
# True detected  0   0.7974683544303798
# False detected  0   0.0
# True detected  5   0
# False detected  5   0
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   5   0.7974683544303798
# True detected  0   0.7974683544303798
# False detected  0   0.0
# True detected  6   0
# False detected  6   1.0
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   6   0.7974683544303798
# True detected  0   0.7974683544303798
# False detected  0   0.0
# True detected  7   0
# False detected  7   1.0
# Better results, id  2
# Worse results, id  1
# Change  4
# AFTER  0   7   0.810126582278481
# True detected  0   0.7974683544303798
# False detected  0   0.0
# True detected  8   0
# False detected  8   1.0
# Better results, id  2
# Worse results, id  4
# Change  8
# AFTER  0   8   0.7721518987341772
# AFTER  0.7721518987341772
# CHURCHMAN BIBLE
# BEFORE  0.5930521091811415
# True detected  0   0.9
# False detected  0   0.021739130434782608
# True detected  1   0.0
# False detected  1   0
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   1   0.5930521091811415
# True detected  0   0.9
# False detected  0   0.021739130434782608
# True detected  2   0.5892857142857143
# False detected  2   0.2978723404255319
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   2   0.5930521091811415
# True detected  0   0.9
# False detected  0   0.021739130434782608
# True detected  3   0.76
# False detected  3   0.4153846153846154
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   3   0.5930521091811415
# True detected  0   0.9
# False detected  0   0.021739130434782608
# True detected  4   0.9230769230769231
# False detected  4   0.6470588235294118
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   4   0.5930521091811415
# True detected  0   0.9
# False detected  0   0.021739130434782608
# True detected  5   0.4666666666666667
# False detected  5   0.7358490566037735
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   5   0.5930521091811415
# True detected  0   0.9
# False detected  0   0.021739130434782608
# True detected  6   0.6091954022988506
# False detected  6   0.38372093023255816
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   6   0.5930521091811415
# True detected  0   0.9
# False detected  0   0.021739130434782608
# True detected  7   0.029411764705882353
# False detected  7   0.0
# Better results, id  0
# Worse results, id  0
# Change  1
# AFTER  0   7   0.5930521091811415
# True detected  0   0.9
# False detected  0   0.021739130434782608
# True detected  8   0.5733333333333334
# False detected  8   0.39436619718309857
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  0   8   0.5905707196029777
# True detected  1   0.0
# False detected  1   0
# True detected  2   0.5892857142857143
# False detected  2   0.2978723404255319
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  1   2   0.5905707196029777
# True detected  1   0.0
# False detected  1   0
# True detected  3   0.76
# False detected  3   0.4153846153846154
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  1   3   0.5905707196029777
# True detected  1   0.0
# False detected  1   0
# True detected  4   0.9230769230769231
# False detected  4   0.6470588235294118
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  1   4   0.5905707196029777
# True detected  1   0.0
# False detected  1   0
# True detected  5   0.4666666666666667
# False detected  5   0.7358490566037735
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  1   5   0.5905707196029777
# True detected  1   0.0
# False detected  1   0
# True detected  6   0.6091954022988506
# False detected  6   0.38372093023255816
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  1   6   0.5905707196029777
# True detected  1   0.0
# False detected  1   0
# True detected  7   0.029411764705882353
# False detected  7   0.0
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  1   7   0.5905707196029777
# True detected  1   0.0
# False detected  1   0
# True detected  8   0.5733333333333334
# False detected  8   0.39436619718309857
# Better results, id  0
# Worse results, id  1
# Change  2
# AFTER  1   8   0.5905707196029777
# True detected  2   0.5892857142857143
# False detected  2   0.2978723404255319
# True detected  3   0.76
# False detected  3   0.4153846153846154
# Better results, id  4
# Worse results, id  2
# Change  8
# AFTER  2   3   0.598014888337469
# True detected  2   0.5892857142857143
# False detected  2   0.2978723404255319
# True detected  4   0.9230769230769231
# False detected  4   0.6470588235294118
# Better results, id  4
# Worse results, id  2
# Change  8
# AFTER  2   4   0.598014888337469
# True detected  2   0.5892857142857143
# False detected  2   0.2978723404255319
# True detected  5   0.4666666666666667
# False detected  5   0.7358490566037735
# Better results, id  4
# Worse results, id  2
# Change  9
# AFTER  2   5   0.598014888337469
# True detected  2   0.5892857142857143
# False detected  2   0.2978723404255319
# True detected  6   0.6091954022988506
# False detected  6   0.38372093023255816
# Better results, id  4
# Worse results, id  3
# Change  10
# AFTER  2   6   0.5955334987593052
# True detected  2   0.5892857142857143
# False detected  2   0.2978723404255319
# True detected  7   0.029411764705882353
# False detected  7   0.0
# Better results, id  4
# Worse results, id  3
# Change  10
# AFTER  2   7   0.5955334987593052
# True detected  2   0.5892857142857143
# False detected  2   0.2978723404255319
# True detected  8   0.5733333333333334
# False detected  8   0.39436619718309857
# Better results, id  4
# Worse results, id  3
# Change  10
# AFTER  2   8   0.5955334987593052
# True detected  3   0.76
# False detected  3   0.4153846153846154
# True detected  4   0.9230769230769231
# False detected  4   0.6470588235294118
# Better results, id  4
# Worse results, id  3
# Change  10
# AFTER  3   4   0.5955334987593052
# True detected  3   0.76
# False detected  3   0.4153846153846154
# True detected  5   0.4666666666666667
# False detected  5   0.7358490566037735
# Better results, id  4
# Worse results, id  4
# Change  11
# AFTER  3   5   0.5930521091811415
# True detected  3   0.76
# False detected  3   0.4153846153846154
# True detected  6   0.6091954022988506
# False detected  6   0.38372093023255816
# Better results, id  4
# Worse results, id  4
# Change  11
# AFTER  3   6   0.5930521091811415
# True detected  3   0.76
# False detected  3   0.4153846153846154
# True detected  7   0.029411764705882353
# False detected  7   0.0
# Better results, id  4
# Worse results, id  4
# Change  11
# AFTER  3   7   0.5930521091811415
# True detected  3   0.76
# False detected  3   0.4153846153846154
# True detected  8   0.5733333333333334
# False detected  8   0.39436619718309857
# Better results, id  4
# Worse results, id  4
# Change  11
# AFTER  3   8   0.5930521091811415
# True detected  4   0.9230769230769231
# False detected  4   0.6470588235294118
# True detected  5   0.4666666666666667
# False detected  5   0.7358490566037735
# Better results, id  5
# Worse results, id  4
# Change  25
# AFTER  4   5   0.5955334987593052
# True detected  4   0.9230769230769231
# False detected  4   0.6470588235294118
# True detected  6   0.6091954022988506
# False detected  6   0.38372093023255816
# Better results, id  6
# Worse results, id  5
# Change  27
# AFTER  4   6   0.5955334987593052
# True detected  4   0.9230769230769231
# False detected  4   0.6470588235294118
# True detected  7   0.029411764705882353
# False detected  7   0.0
# Better results, id  9
# Worse results, id  6
# Change  28
# AFTER  4   7   0.6004962779156328
# True detected  4   0.9230769230769231
# False detected  4   0.6470588235294118
# True detected  8   0.5733333333333334
# False detected  8   0.39436619718309857
# Better results, id  9
# Worse results, id  10
# Change  35
# AFTER  4   8   0.5905707196029777
# True detected  5   0.4666666666666667
# False detected  5   0.7358490566037735
# True detected  6   0.6091954022988506
# False detected  6   0.38372093023255816
# Better results, id  15
# Worse results, id  16
# Change  49
# AFTER  5   6   0.5905707196029777
# True detected  5   0.4666666666666667
# False detected  5   0.7358490566037735
# True detected  7   0.029411764705882353
# False detected  7   0.0
# Better results, id  14
# Worse results, id  16
# Change  48
# AFTER  5   7   0.5880893300248139
# True detected  5   0.4666666666666667
# False detected  5   0.7358490566037735
# True detected  8   0.5733333333333334
# False detected  8   0.39436619718309857
# Better results, id  16
# Worse results, id  16
# Change  56
# AFTER  5   8   0.5930521091811415
# True detected  6   0.6091954022988506
# False detected  6   0.38372093023255816
# True detected  7   0.029411764705882353
# False detected  7   0.0
# Better results, id  15
# Worse results, id  16
# Change  56
# AFTER  6   7   0.5905707196029777
# True detected  6   0.6091954022988506
# False detected  6   0.38372093023255816
# True detected  8   0.5733333333333334
# False detected  8   0.39436619718309857
# Better results, id  20
# Worse results, id  21
# Change  67
# AFTER  6   8   0.5905707196029777
# True detected  7   0.029411764705882353
# False detected  7   0.0
# True detected  8   0.5733333333333334
# False detected  8   0.39436619718309857
# Better results, id  20
# Worse results, id  21
# Change  68
# AFTER  7   8   0.5905707196029777
# AFTER  0.5905707196029777
# CROSS H CATTLE
# BEFORE  0.452
# True detected  0   0
# False detected  0   0
# True detected  1   0.34810126582278483
# False detected  1   0.06779661016949153
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   1   0.452
# True detected  0   0
# False detected  0   0
# True detected  2   0.5319148936170213
# False detected  2   0.5341614906832298
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   2   0.452
# True detected  0   0
# False detected  0   0
# True detected  3   0.6808510638297872
# False detected  3   0.7593984962406015
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   3   0.452
# True detected  0   0
# False detected  0   0
# True detected  4   0.08
# False detected  4   0.5
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   4   0.452
# True detected  0   0
# False detected  0   0
# True detected  5   0.0
# False detected  5   1.0
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   5   0.452
# True detected  0   0
# False detected  0   0
# True detected  6   0.6451612903225806
# False detected  6   0.7222222222222222
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   6   0.452
# True detected  0   0
# False detected  0   0
# True detected  7   0.5
# False detected  7   0.6666666666666666
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   7   0.452
# True detected  0   0
# False detected  0   0
# True detected  8   0.6029411764705882
# False detected  8   0.31666666666666665
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   8   0.452
# True detected  1   0.34810126582278483
# False detected  1   0.06779661016949153
# True detected  2   0.5319148936170213
# False detected  2   0.5341614906832298
# Better results, id  4
# Worse results, id  55
# Change  59
# AFTER  1   2   0.35
# True detected  1   0.34810126582278483
# False detected  1   0.06779661016949153
# True detected  3   0.6808510638297872
# False detected  3   0.7593984962406015
# Better results, id  4
# Worse results, id  55
# Change  59
# AFTER  1   3   0.35
# True detected  1   0.34810126582278483
# False detected  1   0.06779661016949153
# True detected  4   0.08
# False detected  4   0.5
# Better results, id  4
# Worse results, id  55
# Change  59
# AFTER  1   4   0.35
# True detected  1   0.34810126582278483
# False detected  1   0.06779661016949153
# True detected  5   0.0
# False detected  5   1.0
# Better results, id  4
# Worse results, id  55
# Change  59
# AFTER  1   5   0.35
# True detected  1   0.34810126582278483
# False detected  1   0.06779661016949153
# True detected  6   0.6451612903225806
# False detected  6   0.7222222222222222
# Better results, id  4
# Worse results, id  55
# Change  59
# AFTER  1   6   0.35
# True detected  1   0.34810126582278483
# False detected  1   0.06779661016949153
# True detected  7   0.5
# False detected  7   0.6666666666666666
# Better results, id  4
# Worse results, id  55
# Change  59
# AFTER  1   7   0.35
# True detected  1   0.34810126582278483
# False detected  1   0.06779661016949153
# True detected  8   0.6029411764705882
# False detected  8   0.31666666666666665
# Better results, id  4
# Worse results, id  55
# Change  59
# AFTER  1   8   0.35
# True detected  2   0.5319148936170213
# False detected  2   0.5341614906832298
# True detected  3   0.6808510638297872
# False detected  3   0.7593984962406015
# Better results, id  17
# Worse results, id  63
# Change  92
# AFTER  2   3   0.36
# True detected  2   0.5319148936170213
# False detected  2   0.5341614906832298
# True detected  4   0.08
# False detected  4   0.5
# Better results, id  17
# Worse results, id  63
# Change  92
# AFTER  2   4   0.36
# True detected  2   0.5319148936170213
# False detected  2   0.5341614906832298
# True detected  5   0.0
# False detected  5   1.0
# Better results, id  17
# Worse results, id  63
# Change  92
# AFTER  2   5   0.36
# True detected  2   0.5319148936170213
# False detected  2   0.5341614906832298
# True detected  6   0.6451612903225806
# False detected  6   0.7222222222222222
# Better results, id  17
# Worse results, id  63
# Change  92
# AFTER  2   6   0.36
# True detected  2   0.5319148936170213
# False detected  2   0.5341614906832298
# True detected  7   0.5
# False detected  7   0.6666666666666666
# Better results, id  17
# Worse results, id  63
# Change  92
# AFTER  2   7   0.36
# True detected  2   0.5319148936170213
# False detected  2   0.5341614906832298
# True detected  8   0.6029411764705882
# False detected  8   0.31666666666666665
# Better results, id  17
# Worse results, id  63
# Change  92
# AFTER  2   8   0.36
# True detected  3   0.6808510638297872
# False detected  3   0.7593984962406015
# True detected  4   0.08
# False detected  4   0.5
# Better results, id  17
# Worse results, id  63
# Change  94
# AFTER  3   4   0.36
# True detected  3   0.6808510638297872
# False detected  3   0.7593984962406015
# True detected  5   0.0
# False detected  5   1.0
# Better results, id  17
# Worse results, id  63
# Change  94
# AFTER  3   5   0.36
# True detected  3   0.6808510638297872
# False detected  3   0.7593984962406015
# True detected  6   0.6451612903225806
# False detected  6   0.7222222222222222
# Better results, id  17
# Worse results, id  63
# Change  94
# AFTER  3   6   0.36
# True detected  3   0.6808510638297872
# False detected  3   0.7593984962406015
# True detected  7   0.5
# False detected  7   0.6666666666666666
# Better results, id  17
# Worse results, id  64
# Change  95
# AFTER  3   7   0.35800000000000004
# True detected  3   0.6808510638297872
# False detected  3   0.7593984962406015
# True detected  8   0.6029411764705882
# False detected  8   0.31666666666666665
# Better results, id  17
# Worse results, id  64
# Change  96
# AFTER  3   8   0.35800000000000004
# True detected  4   0.08
# False detected  4   0.5
# True detected  5   0.0
# False detected  5   1.0
# Better results, id  21
# Worse results, id  65
# Change  99
# AFTER  4   5   0.364
# True detected  4   0.08
# False detected  4   0.5
# True detected  6   0.6451612903225806
# False detected  6   0.7222222222222222
# Better results, id  20
# Worse results, id  65
# Change  99
# AFTER  4   6   0.362
# True detected  4   0.08
# False detected  4   0.5
# True detected  7   0.5
# False detected  7   0.6666666666666666
# Better results, id  20
# Worse results, id  65
# Change  99
# AFTER  4   7   0.362
# True detected  4   0.08
# False detected  4   0.5
# True detected  8   0.6029411764705882
# False detected  8   0.31666666666666665
# Better results, id  20
# Worse results, id  67
# Change  101
# AFTER  4   8   0.35800000000000004
# True detected  5   0.0
# False detected  5   1.0
# True detected  6   0.6451612903225806
# False detected  6   0.7222222222222222
# Better results, id  20
# Worse results, id  67
# Change  103
# AFTER  5   6   0.35800000000000004
# True detected  5   0.0
# False detected  5   1.0
# True detected  7   0.5
# False detected  7   0.6666666666666666
# Better results, id  20
# Worse results, id  67
# Change  103
# ...
# True detected  0   0
# False detected  0   1.0
# True detected  1   0.0
# False detected  1   1.0
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   1   0.5410628019323671
# True detected  0   0
# False detected  0   1.0
# True detected  2   0.8632478632478633
# False detected  2   0.24060150375939848
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   2   0.5410628019323671
# True detected  0   0
# False detected  0   1.0
# True detected  3   0.6176470588235294
# False detected  3   0.288135593220339
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   3   0.5410628019323671
# True detected  0   0
# False detected  0   1.0
# True detected  4   0.10714285714285714
# False detected  4   0.25
# Better results, id  0
# Worse results, id  0
# Change  2
# AFTER  0   4   0.5410628019323671
# True detected  0   0
# False detected  0   1.0
# True detected  5   0.0851063829787234
# False detected  5   0.75
# Better results, id  0
# Worse results, id  0
# Change  2
# AFTER  0   5   0.5410628019323671
# True detected  0   0
# False detected  0   1.0
# True detected  6   0.43333333333333335
# False detected  6   0.803030303030303
# Better results, id  0
# Worse results, id  1
# Change  6
# AFTER  0   6   0.538647342995169
# True detected  0   0
# False detected  0   1.0
# True detected  7   1.0
# False detected  7   0.6
# Better results, id  0
# Worse results, id  1
# Change  8
# AFTER  0   7   0.538647342995169
# True detected  0   0
# False detected  0   1.0
# True detected  8   0.49137931034482757
# False detected  8   0.2875
# Better results, id  1
# Worse results, id  1
# Change  11
# AFTER  0   8   0.5410628019323671
# True detected  1   0.0
# False detected  1   1.0
# True detected  2   0.8632478632478633
# False detected  2   0.24060150375939848
# Better results, id  4
# Worse results, id  1
# Change  14
# AFTER  1   2   0.5483091787439613
# True detected  1   0.0
# False detected  1   1.0
# True detected  3   0.6176470588235294
# False detected  3   0.288135593220339
# Better results, id  4
# Worse results, id  1
# Change  14
# AFTER  1   3   0.5483091787439613
# True detected  1   0.0
# False detected  1   1.0
# True detected  4   0.10714285714285714
# False detected  4   0.25
# Better results, id  4
# Worse results, id  1
# Change  14
# AFTER  1   4   0.5483091787439613
# True detected  1   0.0
# False detected  1   1.0
# True detected  5   0.0851063829787234
# False detected  5   0.75
# Better results, id  4
# Worse results, id  1
# Change  14
# AFTER  1   5   0.5483091787439613
# True detected  1   0.0
# False detected  1   1.0
# True detected  6   0.43333333333333335
# False detected  6   0.803030303030303
# Better results, id  4
# Worse results, id  1
# Change  14
# AFTER  1   6   0.5483091787439613
# True detected  1   0.0
# False detected  1   1.0
# True detected  7   1.0
# False detected  7   0.6
# Better results, id  4
# Worse results, id  1
# Change  14
# AFTER  1   7   0.5483091787439613
# True detected  1   0.0
# False detected  1   1.0
# True detected  8   0.49137931034482757
# False detected  8   0.2875
# Better results, id  4
# Worse results, id  1
# Change  14
# AFTER  1   8   0.5483091787439613
# True detected  2   0.8632478632478633
# False detected  2   0.24060150375939848
# True detected  3   0.6176470588235294
# False detected  3   0.288135593220339
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  2   3   0.5555555555555556
# True detected  2   0.8632478632478633
# False detected  2   0.24060150375939848
# True detected  4   0.10714285714285714
# False detected  4   0.25
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  2   4   0.5555555555555556
# True detected  2   0.8632478632478633
# False detected  2   0.24060150375939848
# True detected  5   0.0851063829787234
# False detected  5   0.75
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  2   5   0.5555555555555556
# True detected  2   0.8632478632478633
# False detected  2   0.24060150375939848
# True detected  6   0.43333333333333335
# False detected  6   0.803030303030303
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  2   6   0.5555555555555556
# True detected  2   0.8632478632478633
# False detected  2   0.24060150375939848
# True detected  7   1.0
# False detected  7   0.6
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  2   7   0.5555555555555556
# True detected  2   0.8632478632478633
# False detected  2   0.24060150375939848
# True detected  8   0.49137931034482757
# False detected  8   0.2875
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  2   8   0.5555555555555556
# True detected  3   0.6176470588235294
# False detected  3   0.288135593220339
# True detected  4   0.10714285714285714
# False detected  4   0.25
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  3   4   0.5555555555555556
# True detected  3   0.6176470588235294
# False detected  3   0.288135593220339
# True detected  5   0.0851063829787234
# False detected  5   0.75
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  3   5   0.5555555555555556
# True detected  3   0.6176470588235294
# False detected  3   0.288135593220339
# True detected  6   0.43333333333333335
# False detected  6   0.803030303030303
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  3   6   0.5555555555555556
# True detected  3   0.6176470588235294
# False detected  3   0.288135593220339
# True detected  7   1.0
# False detected  7   0.6
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  3   7   0.5555555555555556
# True detected  3   0.6176470588235294
# False detected  3   0.288135593220339
# True detected  8   0.49137931034482757
# False detected  8   0.2875
# Better results, id  11
# Worse results, id  5
# Change  28
# AFTER  3   8   0.5555555555555556
# True detected  4   0.10714285714285714
# False detected  4   0.25
# True detected  5   0.0851063829787234
# False detected  5   0.75
# Better results, id  12
# Worse results, id  5
# Change  31
# AFTER  4   5   0.5579710144927537
# True detected  4   0.10714285714285714
# False detected  4   0.25
# True detected  6   0.43333333333333335
# False detected  6   0.803030303030303
# Better results, id  13
# Worse results, id  5
# Change  32
# AFTER  4   6   0.5603864734299517
# True detected  4   0.10714285714285714
# False detected  4   0.25
# True detected  7   1.0
# False detected  7   0.6
# Better results, id  13
# Worse results, id  5
# Change  32
# AFTER  4   7   0.5603864734299517
# True detected  4   0.10714285714285714
# False detected  4   0.25
# True detected  8   0.49137931034482757
# False detected  8   0.2875
# Better results, id  13
# Worse results, id  5
# Change  32
# AFTER  4   8   0.5603864734299517
# True detected  5   0.0851063829787234
# False detected  5   0.75
# True detected  6   0.43333333333333335
# False detected  6   0.803030303030303
# Better results, id  19
# Worse results, id  5
# Change  40
# AFTER  5   6   0.5748792270531401
# True detected  5   0.0851063829787234
# False detected  5   0.75
# True detected  7   1.0
# False detected  7   0.6
# Better results, id  18
# Worse results, id  6
# Change  41
# AFTER  5   7   0.5700483091787439
# True detected  5   0.0851063829787234
# False detected  5   0.75
# True detected  8   0.49137931034482757
# False detected  8   0.2875
# Better results, id  19
# Worse results, id  6
# Change  41
# AFTER  5   8   0.572463768115942
# True detected  6   0.43333333333333335
# False detected  6   0.803030303030303
# True detected  7   1.0
# False detected  7   0.6
# Better results, id  19
# Worse results, id  7
# Change  46
# AFTER  6   7   0.5700483091787439
# True detected  6   0.43333333333333335
# False detected  6   0.803030303030303
# True detected  8   0.49137931034482757
# False detected  8   0.2875
# Better results, id  19
# Worse results, id  12
# Change  55
# AFTER  6   8   0.5579710144927537
# True detected  7   1.0
# False detected  7   0.6
# True detected  8   0.49137931034482757
# False detected  8   0.2875
# Better results, id  18
# Worse results, id  12
# Change  57
# AFTER  7   8   0.5555555555555556
# AFTER  0.5555555555555556
# ALEXANDER D
# BEFORE  0.6365591397849463
# True detected  0   0.0
# False detected  0   0
# True detected  2   0.8632478632478633
# False detected  2   0.18548387096774194
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   2   0.6365591397849463
# True detected  0   0.0
# False detected  0   0
# True detected  3   0.7444444444444445
# False detected  3   0.1728395061728395
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   3   0.6365591397849463
# True detected  0   0.0
# False detected  0   0
# True detected  4   0.8863636363636364
# False detected  4   0.4264705882352941
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   4   0.6365591397849463
# True detected  0   0.0
# False detected  0   0
# True detected  5   0.46153846153846156
# False detected  5   0.7735849056603774
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   5   0.6365591397849463
# True detected  0   0.0
# False detected  0   0
# True detected  6   0.028985507246376812
# False detected  6   0.8
# Better results, id  0
# Worse results, id  0
# Change  0
# AFTER  0   6   0.6365591397849463
# True detected  0   0.0
# False detected  0   0
# True detected  7   0.5625
# False detected  7   0.71875
# Better results, id  0
# Worse results, id  0
# Change  2
# AFTER  0   7   0.6365591397849463
# True detected  0   0.0
# False detected  0   0
# True detected  8   0.673469387755102
# False detected  8   0.31958762886597936
# Better results, id  1
# Worse results, id  1
# Change  6
# AFTER  0   8   0.6365591397849463
# True detected  1   0
# False detected  1   0
# True detected  2   0.8632478632478633
# False detected  2   0.18548387096774194
# Better results, id  1
# Worse results, id  1
# Change  6
# AFTER  1   2   0.6365591397849463
# True detected  1   0
# False detected  1   0
# True detected  3   0.7444444444444445
# False detected  3   0.1728395061728395
# Better results, id  1
# Worse results, id  1
# Change  6
# AFTER  1   3   0.6365591397849463
# True detected  1   0
# False detected  1   0
# True detected  4   0.8863636363636364
# False detected  4   0.4264705882352941
# Better results, id  1
# Worse results, id  1
# Change  6
# AFTER  1   4   0.6365591397849463
# True detected  1   0
# False detected  1   0
# True detected  5   0.46153846153846156
# False detected  5   0.7735849056603774
# Better results, id  1
# Worse results, id  1
# Change  6
# AFTER  1   5   0.6365591397849463
# True detected  1   0
# False detected  1   0
# True detected  6   0.028985507246376812
# False detected  6   0.8
# Better results, id  1
# Worse results, id  1
# Change  6
# AFTER  1   6   0.6365591397849463
# True detected  1   0
# False detected  1   0
# True detected  7   0.5625
# False detected  7   0.71875
# Better results, id  1
# Worse results, id  1
# Change  6
# AFTER  1   7   0.6365591397849463
# True detected  1   0
# False detected  1   0
# True detected  8   0.673469387755102
# False detected  8   0.31958762886597936
# Better results, id  1
# Worse results, id  1
# Change  6
# AFTER  1   8   0.6365591397849463
# True detected  2   0.8632478632478633
# False detected  2   0.18548387096774194
# True detected  3   0.7444444444444445
# False detected  3   0.1728395061728395
# Better results, id  4
# Worse results, id  10
# Change  18
# AFTER  2   3   0.6236559139784946
# True detected  2   0.8632478632478633
# False detected  2   0.18548387096774194
# True detected  4   0.8863636363636364
# False detected  4   0.4264705882352941
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  2   4   0.6258064516129033
# True detected  2   0.8632478632478633
# False detected  2   0.18548387096774194
# True detected  5   0.46153846153846156
# False detected  5   0.7735849056603774
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  2   5   0.6258064516129033
# True detected  2   0.8632478632478633
# False detected  2   0.18548387096774194
# True detected  6   0.028985507246376812
# False detected  6   0.8
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  2   6   0.6258064516129033
# True detected  2   0.8632478632478633
# False detected  2   0.18548387096774194
# True detected  7   0.5625
# False detected  7   0.71875
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  2   7   0.6258064516129033
# True detected  2   0.8632478632478633
# False detected  2   0.18548387096774194
# True detected  8   0.673469387755102
# False detected  8   0.31958762886597936
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  2   8   0.6258064516129033
# True detected  3   0.7444444444444445
# False detected  3   0.1728395061728395
# True detected  4   0.8863636363636364
# False detected  4   0.4264705882352941
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  3   4   0.6258064516129033
# True detected  3   0.7444444444444445
# False detected  3   0.1728395061728395
# True detected  5   0.46153846153846156
# False detected  5   0.7735849056603774
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  3   5   0.6258064516129033
# True detected  3   0.7444444444444445
# False detected  3   0.1728395061728395
# True detected  6   0.028985507246376812
# False detected  6   0.8
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  3   6   0.6258064516129033
# True detected  3   0.7444444444444445
# False detected  3   0.1728395061728395
# True detected  7   0.5625
# False detected  7   0.71875
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  3   7   0.6258064516129033
# True detected  3   0.7444444444444445
# False detected  3   0.1728395061728395
# True detected  8   0.673469387755102
# False detected  8   0.31958762886597936
# Better results, id  5
# Worse results, id  10
# Change  19
# AFTER  3   8   0.6258064516129033
# True detected  4   0.8863636363636364
# False detected  4   0.4264705882352941
# True detected  5   0.46153846153846156
# False detected  5   0.7735849056603774
# Better results, id  5
# Worse results, id  10
# Change  23
# AFTER  4   5   0.6258064516129033
# True detected  4   0.8863636363636364
# False detected  4   0.4264705882352941
# True detected  6   0.028985507246376812
# False detected  6   0.8
# Better results, id  6
# Worse results, id  13
# Change  27
# AFTER  4   6   0.621505376344086
# True detected  4   0.8863636363636364
# False detected  4   0.4264705882352941
# True detected  7   0.5625
# False detected  7   0.71875
# Better results, id  5
# Worse results, id  13
# Change  27
# AFTER  4   7   0.6193548387096774
# True detected  4   0.8863636363636364
# False detected  4   0.4264705882352941
# True detected  8   0.673469387755102
# False detected  8   0.31958762886597936
# Better results, id  5
# Worse results, id  15
# Change  37
# AFTER  4   8   0.6150537634408603
# True detected  5   0.46153846153846156
# False detected  5   0.7735849056603774
# True detected  6   0.028985507246376812
# False detected  6   0.8
# Better results, id  5
# Worse results, id  15
# Change  40
# AFTER  5   6   0.6150537634408603
# True detected  5   0.46153846153846156
# False detected  5   0.7735849056603774
# True detected  7   0.5625
# False detected  7   0.71875
# Better results, id  8
# Worse results, id  15
# Change  45
# AFTER  5   7   0.621505376344086
# True detected  5   0.46153846153846156
# False detected  5   0.7735849056603774
# True detected  8   0.673469387755102
# False detected  8   0.31958762886597936
# Better results, id  8
# Worse results, id  27
# Change  63
# AFTER  5   8   0.5956989247311828
# True detected  6   0.028985507246376812
# False detected  6   0.8
# True detected  7   0.5625
# False detected  7   0.71875
# Better results, id  8
# Worse results, id  28
# Change  64
# AFTER  6   7   0.5935483870967742
# True detected  6   0.028985507246376812
# False detected  6   0.8
# True detected  8   0.673469387755102
# False detected  8   0.31958762886597936
# Better results, id  10
# Worse results, id  28
# Change  67
# AFTER  6   8   0.5978494623655914
# True detected  7   0.5625
# False detected  7   0.71875
# True detected  8   0.673469387755102
# False detected  8   0.31958762886597936
# Better results, id  9
# Worse results, id  33
# Change  78
# AFTER  7   8   0.5849462365591398
# AFTER  0.5849462365591398
# well, boosting of trees,  0.5838725217994958
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ba6f93d0eaf3> in <module>()
#     132     most_similar(yhat_labels, y_test)
#     133 print('well, boosting of trees, ', acc/10)
# --> 134 print('well, boosting of trees 68, ', acc_68/9)
#     135 print(change)
#
# NameError: name 'acc_68' is not defined
